# %%
import requests
import datetime
import calendar
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.basemap import shiftgrid
import matplotlib.colors as colors

"""filename = "test.nc"
data = Dataset(filename)
print(data.variables.keys())
pr = data.variables['pr'][:]
print(pr)
print(np.shape(pr))
pr=pr.flatten()
plt.figure()
plt.plot(np.arange(1,32,1),pr)
plt.xlim(1, 32)
plt.ylim(0, max(pr)) 
plt.title("Oborina u Zagrebu, prosinac 2005")
plt.xlabel("dan") 
plt.ylabel(u"pr") 
plt.show()"""

# PR,TAS FILE DOWNLOAD

"""#--CN
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp45/pr_CRO_CN_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp45/tas_CRO_CN_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp85/pr_CRO_CN_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp85/tas_CRO_CN_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_historical/pr_CRO_CN_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_historical/tas_CRO_CN_STS.'

#--EC
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp45/pr_CRO_EC_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp45/tas_CRO_EC_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_historical/pr_CRO_EC_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_historical/tas_CRO_EC_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp85/pr_CRO_EC_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp85/tas_CRO_EC_85_STS.'

#--MP
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp45/pr_CRO_MP_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp45/tas_CRO_MP_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp85/pr_CRO_MP_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp85/tas_CRO_MP_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_historical/pr_CRO_MP_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_historical/tas_CRO_MP_STS.'

#--HA
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp45/pr_CRO_HA_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp45/tas_CRO_HA_45_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp85/pr_CRO_HA_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp85/tas_CRO_HA_85_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_historical/pr_CRO_HA_STS.'
#url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_historical/tas_CRO_HA_STS.'


end= '00.nc'


x=datetime.date(2005,12,1)
last_date=datetime.date(2070,12,1)

#x=datetime.date(1970,1,1)
#last_date=datetime.date(2005,11,1)


while x<=last_date:
    
    day_in_mon=calendar.monthrange(x.year,x.month)[1]
    delta=datetime.timedelta(days=day_in_mon)
    print(x)
    dat=x.strftime('%Y')+x.strftime('%m')+x.strftime('%d')
    url=url1+dat+end
    r = requests.get(url, allow_redirects=True)
    
    #--CN
    #open('pr_CRO_CN_45_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_CN_45_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_CN_85_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_CN_85_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_CN_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_CN_STS.'+dat+end, 'wb').write(r.content)
    #--EC
    #open('pr_CRO_EC_45_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_EC_45_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_EC_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_EC_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_EC_85_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_EC_85_STS.'+dat+end, 'wb').write(r.content)
    #--MP
    #open('pr_CRO_MP_45_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_MP_45_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_MP_85_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_MP_85_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_MP_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_MP_STS.'+dat+end, 'wb').write(r.content)
    #--HA
    #open('pr_CRO_HA_45_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_HA_45_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_HA_85_STS.'+dat+end, 'wb').write(r.content)
    #open('tas_CRO_HA_85_STS.'+dat+end, 'wb').write(r.content)
    #open('pr_CRO_HA_STS.'+dat+end, 'wb').write(r.content)
    #('tas_CRO_HA_STS.'+dat+end, 'wb').write(r.content)
    
    x+=delta"""
    

# TASMIN TASMAX FILE DOWNLOAD za rcp4.5 i rcp8.5
"""GCM=['CN','EC','MP','HA']
VAR=['tasmax','tasmin']
SCEN=['45','85']
for g in np.arange(0,4):
    for v in np.arange(0,2):
        for s in np.arange(0,2):
            url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_{}/EXP_rcp{}/{}_CRO_{}_{}_STS.'.format(GCM[g],SCEN[s],VAR[v],GCM[g],SCEN[s])

            end= '00.nc'


            x=datetime.date(2005,12,1)
            last_date=datetime.date(2070,12,1)


            while x<=last_date:
    
                day_in_mon=calendar.monthrange(x.year,x.month)[1]
                delta=datetime.timedelta(days=day_in_mon)
                print(x)
                dat=x.strftime('%Y')+x.strftime('%m')+x.strftime('%d')
                url=url1+dat+end
                r = requests.get(url, allow_redirects=True)
                
                ime='{}_CRO_{}_{}_STS.'.format(VAR[v],GCM[g],SCEN[s])
                path='C:/--PRAKSA--/podaci/{}/{}_{}/'.format(GCM[g],VAR[v],SCEN[s])
                open(path+ime+dat+end, 'wb').write(r.content)
                
                x+=delta
    
#FILE DOWNLOAD za hist
GCM=['CN','EC','MP','HA']
VAR=['tasmax','tasmin']
for g in np.arange(0,4):
    for v in np.arange(0,2):
        url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_{}/EXP_historical/{}_CRO_{}_STS.'.format(GCM[g],VAR[v],GCM[g])
        #url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_historical/tasmax_CRO_CN_STS.'
        
        end= '00.nc'


        x=datetime.date(1970,1,1)
        last_date=datetime.date(2005,11,1)


        while x<=last_date:
    
            day_in_mon=calendar.monthrange(x.year,x.month)[1]
            delta=datetime.timedelta(days=day_in_mon)
            print(x)
            dat=x.strftime('%Y')+x.strftime('%m')+x.strftime('%d')
            url=url1+dat+end
            r = requests.get(url, allow_redirects=True)
                
            ime='{}_CRO_{}_STS.'.format(VAR[v],GCM[g])
            path='C:/--PRAKSA--/podaci/{}/{}_hist/'.format(GCM[g],VAR[v])
            open(path+ime+dat+end, 'wb').write(r.content)
                
            x+=delta    """

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt



fig = plt.figure(figsize=(15,19))

#Setting up lambert conformal basemap (lcc)
#lon_0,lat_0 is the central point
#lat_1 is first standard parallel (defaults to lat_0)
#lat_2 is second standard parallel (defaults to lat_1)
#Full resolution, 'f'
#Lower left corner longitude=llcrnrlon, etc.
m = Basemap(llcrnrlon=13.2, llcrnrlat=42.2, urcrnrlon=19.6,
  urcrnrlat=46.6, projection='lcc', lat_0=44.4, lon_0=16.3, resolution='f')


#Draw land/ocean/lake mask, coastlines and country borders
m.drawlsmask(land_color='white', ocean_color='white', lakes=True)
m.drawcoastlines()
m.drawcountries(color='black')

#Draw parallels and meridians
m.drawparallels(np.arange(42.2,46.6,0.1),labels=[True,False,False,False],linewidth=0)
m.drawmeridians(np.arange(13.2,19.6,0.1),labels=[0,0,0,1],rotation=90.,linewidth=0)
#np.arange(start,stop,step)
#labels=[left,right,top,bottom]

ax = plt.gca() #Get current axes

#m.shadedrelief() #Include relief in the map

LON=np.zeros(21)
LAT=np.zeros(21)
MARK=[' ']*21 #An empty list of strings containing 21 elements

LON[0]=14.3166654 ; LAT[0]=45.3499986; MARK[0]='Volosko'
LON[1]=15.966568 ; LAT[1]=45.815399; MARK[1]='Zagreb'
LON[2]=15.87889 ; LAT[2]=46.16083; MARK[2]='Krapina'

LON[3]=16.37833 ; LAT[3]=45.46611; MARK[3]='Sisak'
LON[4]=15.54778 ; LAT[4]=45.48722; MARK[4]='Karlovac'
LON[5]=16.33778 ; LAT[5]=46.30444; MARK[5]='Varaždin'

LON[6]=16.8275 ; LAT[6]=46.16278; MARK[6]='Koprivnica'
LON[7]=16.84889 ; LAT[7]=45.89861; MARK[7]='Bjelovar'
LON[8]=14.40917 ; LAT[8]=45.34306; MARK[8]='Rijeka'

LON[9]=16.43915 ; LAT[9]=43.50891; MARK[9]='Split'
LON[10]=13.93667 ; LAT[10]=45.24028; MARK[10]='Pazin'
LON[11]=15.37472 ; LAT[11]=44.54611; MARK[11]='Gospić'

LON[12]=17.38389 ; LAT[12]=45.83194; MARK[12]='Virovitica'
LON[13]=17.68528 ; LAT[13]=45.34028; MARK[13]='Požega'
LON[14]=18.01556 ; LAT[14]=45.16028; MARK[14]='Slavonski Brod'

LON[15]=15.24222 ; LAT[15]=44.11972; MARK[15]='Zadar'
LON[16]=18.69389 ; LAT[16]=45.55111; MARK[16]='Osijek'
LON[17]=15.90583 ; LAT[17]=43.72722; MARK[17]='Šibenik'

LON[18]=18.99972 ; LAT[18]=45.34333; MARK[18]='Vukovar'
LON[19]=18.09216 ; LAT[19]=42.64807; MARK[19]='Dubrovnik'
LON[20]=16.43389 ; LAT[20]=46.38444; MARK[20]='Čakovec'

for i in np.arange(0,21,1):
    x, y = m(LON[i], LAT[i])
    plt.plot(x, y, 'or', markersize=5) #Scattering, plotting markers as red dots
    plt.text(x+2000, y+2000, MARK[i], fontsize=12) #Plotting text next to the points (2000 (x) & 2000 (y) points away from the marker)
plt.title('Lambert Conformal Projection', fontsize=20)

plt.show()

# %%
#---CRTANJE VIŠEGODIŠNJIH MJESEČNIH SREDNJAKA PR, TAS I OBS ZA SVAKU POSTAJU

from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap


#Definiram funkciju za crtanje
def crtaj(ax,var,yLab,tit,color,linewidth,lab):#,yLim):
    x=np.arange(1,13)
    ax.plot(x,var,color=color,linewidth=linewidth,label=lab)
    ax.grid(b=True)
    ax.set_xlabel('Mjesec')
    ax.set_xticks(np.arange(1,13,1))
    ax.set_xlim([0.5, 12.5])
    ax.set_ylabel(yLab)
    #ax.set_ylim(yLim)
    ax.set_title(tit)
    ax.legend()
    return



GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['pr','tas'] #VAR[v]
SCEN=['45','85'] #SCEN[s]

#----Dobavljam datoteke

for i in np.arange(1,22): #petlja po stanicama
    fig, ax=plt.subplots(4,2, figsize=(20,13))
    fig.tight_layout(pad=4.0)
    fig.subplots_adjust(top=0.95,bottom=0.1)
    fig.suptitle(MARK[i-1],fontsize=17)
    
    #-If petlja u kojoj se skupljaju opazene vrijednosti pr i tas
    if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20: #2,4,6,9..su redni brojevi stanica za koje imam opazene podatke
        #Otvara datoteku
        f=open('C:/--PRAKSA--/opazanja/{}.dat'.format(MARK[i-1]))
        #Ucitava podatke
        pom=np.loadtxt(f,comments='%')[:,:]
        tas_op=pom[0,:]
        pr_op=pom[1,:]
    
    for g in np.arange(0,4): #petlja po GCM
                
        for v in np.arange(0,2): #petlja po VAR
            yLab=VAR[v]
            tit=GCM[g]+' '+VAR[v]
            
            #---Za historijsku klimu
            
            s=0 #Historijska klima je ista za oba scenarija, RCP 4.5 i RCP 8.5
            
            color='green' #Za historijsku klimu imat ću zelenu liniju
            linewidth=1; 
                
            if v==0:                
                #-If petlja za opazene podatke, crtam ih crno:
                if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20:
                    lab='Opazanje'
                    crtaj(ax[g,v], var=pr_op, yLab=yLab, tit=tit, color='black', linewidth=linewidth, lab=lab)#, yLim=yLim                pr = nc.variables['pr'][:] # precipitation [mm]
                #Folder u kojem se svi historijski podaci nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P0_ymonmean_monsum_STATION_1_CN_pr_45.nc
                nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P0_ymonmean_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                pr=nc.variables['pr'][:] #precipitation [mm]
                pr=pr.flatten()
                yLim=[0,515] #mm stupca vode
                lab='Hist P0'
                crtaj(ax[g,v], var=pr, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                
            elif v==1:
                #-If petlja za opazene podatke, crtam ih crno:
                if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20:
                    lab='Opazanje'
                    crtaj(ax[g,v], var=tas_op, yLab=yLab, tit=tit, color='black', linewidth=linewidth, lab=lab)#, yLim=yLim)
                #Folder u kojem se svi historijski podaci nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P0_ymonmean_monmean_STATION_1_CN_tas_45.nc
                nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P0_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                tas=nc.variables['tas'][:] #2m mean temperature [C]
                tas=tas.flatten()
                yLim=[-5,35] #stupnjeva Celzijusa
                lab='Hist P0'
                crtaj(ax[g,v], var=tas, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                
                      
            #---Za buduću klimu
            
            for s in np.arange(0,2): #petlja po scenarijima
                
                if s==0:
                    lab='RCM 4.5 (P2)' 
                    color='blue' #RCP 4.5 podatke crtati ću plavom linijom
                    linewidth=1.5;
                elif s==1:
                    lab='RCM 8.5 (P2)' 
                    color='red'; #RCP 8.5 podatke crtati ću crvenom linijom
                    linewidth=2; 
                
                if v==0:
                    #Folder u kojem se svi podaci buduće klime nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P2_ymonmean_monsum_STATION_1_CN_pr_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P2_ymonmean_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    pr = nc.variables['pr'][:] # precipitation [mm]
                    pr=pr.flatten()
                    yLim=[0,515] #mm stupca vode
                    crtaj(ax[g,v], var=pr, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                elif v==1:
                    #Folder u kojem se svi podaci buduće klime nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P2_ymonmean_monmean_STATION_1_CN_tas_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P2_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))                    
                    tas=nc.variables['tas'][:] #2m mean temperature [C]
                    tas=tas.flatten()
                    yLim=[-5,35] #stupnjeva Celzijusa
                    crtaj(ax[g,v], var=tas, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
    #fig.savefig('{}.png'.format(MARK[i-1]))

# %%
#---CRTANJE VIŠEGODIŠNJIH MJESEČNIH SREDNJAKA TASMAX, TASMIN I OBS ZA SVAKU POSTAJU
from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap


#Definiram funkciju za crtanje
def crtaj(ax,var,yLab,tit,color,linewidth,lab):#,yLim):
    x=np.arange(1,13)
    ax.plot(x,var,color=color,linewidth=linewidth,label=lab)
    ax.grid(b=True)
    ax.set_xlabel('Mjesec')
    ax.set_xticks(np.arange(1,13,1))
    ax.set_xlim([0.5, 12.5])
    ax.set_ylabel(yLab)
    #ax.set_ylim(yLim)
    ax.set_title(tit)
    ax.legend()
    return



GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['tasmax','tasmin'] #VAR[v]
SCEN=['45','85'] #SCEN[s]

#----Dobavljam datoteke

for i in np.arange(1,22): #petlja po stanicama
    fig, ax=plt.subplots(4,2, figsize=(20,13))
    fig.tight_layout(pad=4.0)
    fig.subplots_adjust(top=0.95,bottom=0.1)
    fig.suptitle(MARK[i-1],fontsize=17)
    
    #-If petlja u kojoj se skupljaju opazene vrijednosti tasmax i tasmin
    if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20: #2,4,6,9..su redni brojevi stanica za koje imam opazene podatke
        #Otvara datoteku
        f=open('C:/--PRAKSA--/opazanja/{}.dat'.format(MARK[i-1]))
        #Ucitava podatke
        pom=np.loadtxt(f,comments='%')[:,:]
        tasmax_op=pom[2,:]
        tasmin_op=pom[3,:]
    
    for g in np.arange(0,4): #petlja po GCM
                
        for v in np.arange(0,2): #petlja po VAR
            yLab=VAR[v]
            tit=GCM[g]+' '+VAR[v]
            
            #---Za historijsku klimu
            
            s=0 #Historijska klima je ista za oba scenarija, RCP 4.5 i RCP 8.5
            
            color='green' #Za historijsku klimu imat ću zelenu liniju
            linewidth=1; 
                
            if v==0:                
                #-If petlja za opazene podatke, crtam ih crno:
                if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20:
                    lab='Opazanje'
                    crtaj(ax[g,v], var=tasmax_op, yLab=yLab, tit=tit, color='black', linewidth=linewidth, lab=lab)#, yLim=yLim                pr = nc.variables['pr'][:] # precipitation [mm]
                #Folder u kojem se svi historijski podaci nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P0_ymonmean_monmean_STATION_1_CN_tasmax_45.nc
                nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P0_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                tasmax=nc.variables['tasmax'][:] #precipitation [mm]
                tasmax=tasmax.flatten()
                yLim=[-5,35] #stupnjeva Celzijusa
                lab='Hist P0'
                crtaj(ax[g,v], var=tasmax, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                
            elif v==1:
                #-If petlja za opazene podatke, crtam ih crno:
                if i==2 or i==4 or i==6 or i==9 or i==10 or i==11 or i==12 or i==15 or i==16 or i==17 or i==20:
                    lab='Opazanje'
                    crtaj(ax[g,v], var=tasmin_op, yLab=yLab, tit=tit, color='black', linewidth=linewidth, lab=lab)#, yLim=yLim)
                #Folder u kojem se svi historijski podaci nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P0_ymonmean_STATION_1_CN_tasmin_45.nc
                nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P0_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                tasmin=nc.variables['tasmin'][:] #2m mean minimum temperature [C]
                tasmin=tasmin.flatten()
                yLim=[-5,35] #stupnjeva Celzijusa
                lab='Hist P0'
                crtaj(ax[g,v], var=tasmin, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                
                      
            #---Za buduću klimu
            
            for s in np.arange(0,2): #petlja po scenarijima
                
                if s==0:
                    lab='RCM 4.5 (P2)' 
                    color='blue' #RCP 4.5 podatke crtati ću plavom linijom
                    linewidth=1.5;
                elif s==1:
                    lab='RCM 8.5 (P2)' 
                    color='red'; #RCP 8.5 podatke crtati ću crvenom linijom
                    linewidth=2; 
                
                if v==0:
                    #Folder u kojem se svi podaci buduće klime nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P2_ymonmean_monmean_STATION_1_CN_tasmax_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P2_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    tasmax = nc.variables['tasmax'][:] #2m mean maximum temperature [C]
                    tasmax=tasmax.flatten()
                    yLim=[-5,35] #mm stupca vode
                    crtaj(ax[g,v], var=tasmax, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
                elif v==1:
                    #Folder u kojem se svi podaci buduće klime nalaze zove se ymonmean_P0_P2, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/ymonmean_P0_P2/CN/pr_45/P2_ymonmean_monmean_STATION_1_CN_tasmin_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/ymonmean_P0_P2/{}/{}_{}/P2_ymonmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))                    
                    tasmin=nc.variables['tasmin'][:] #2m mean minimum temperature [C]
                    tasmin=tasmin.flatten()
                    yLim=[-5,35] #stupnjeva Celzijusa
                    crtaj(ax[g,v], var=tasmin, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab)#, yLim=yLim)
    #fig.savefig('{}.png'.format(MARK[i-1]))

# %%
#----CRTANJE VREMENSKIH NIZOVA UKUPNIH GODIŠNJIH KOLIČINA OBORINE I SREDNJIH GODIŠNJIH TEMPERATURA (PR, TAS) ZA SVAKU POSTAJU

from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap


#---Definiram funkciju za crtanje
def crtajniz(ax,var,yLab,tit,color,linewidth,lab,a,b,tex):#,yLim):
    x=np.arange(1971,2072)
    ax.plot(x,var,color=color,linewidth=linewidth,label=lab)
    
    x_pom=np.arange(0,101)
    y=(a*x_pom)+b
    ax.plot(x,y,color=color,linewidth=linewidth)
    
    ax.set_xticks(np.arange(1970,2072,5))
    ax.set_xticklabels(np.arange(1970,2072,5), fontsize=17)# Rotation=90.
    ax.set_xlim([1970,2072])
    ax.set_xlabel('Godina', fontsize=20)
    #ax.annotate(tex, xy=(100, a*100+b), xytext=(2072, a*100+b))
    ax.text(2071, a*100+b, tex, color=color, fontsize=17)

    ax.set_ylabel(yLab, fontsize=20)
    ytlabs=ax.get_yticks()
    ytlabs = [int(x) for x in ytlabs]
    ax.set_yticklabels(ytlabs,fontsize=17)
    #ax.set_ylim(yLim)
    
    ax.set_title(tit, fontsize=22)
    ax.legend(fontsize='xx-large')
    ax.grid(b=True)
    return


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['pr','tas'] #VAR[v]
SCEN=['45','85'] #SCEN[s]

#---Dobavljam datoteke

for i in np.arange(1,22): #petlja po stanicama
    fig, ax=plt.subplots(4,2, figsize=(45,30))
    fig.subplots_adjust(top=0.96,bottom=0.09)
    fig.suptitle(MARK[i-1],fontsize=27)
    
    for g in np.arange(0,4): #petlja po GCM
                
        for v in np.arange(0,2): #petlja po VAR
            tit=GCM[g]+' '+VAR[v]
                                                   
            for s in np.arange(0,2): #petlja po scenarijima
                
                if s==0:
                    lab='RCM 4.5'
                    color='blue' #RCP 4.5 podatke crtati ću plavom linijom
                    linewidth=2;
                elif s==1:
                    lab='RCM 8.5'
                    color='red'; #RCP 8.5 podatke crtati ću crvenom linijom
                    linewidth=2.5; 
                
                if v==0:
                    yLab='Oborina [mm]'

                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi podaci zove se yearsum_yearmean, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/yearsum_yearmean/CN/pr_85/yearsum_monsum_STATION_1_CN_pr_85.nc
                    nc = NetCDFFile('C:/--PRAKSA--/yearsum_yearmean/{}/{}_{}/yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    pr = nc.variables['pr'][:] #precipitation [mm]
                    pr=pr.flatten()
                    
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/pr_45/trenda_yearsum_monsum_STATION_1_CN_pr_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['pr'][:]
                    a=a.flatten()
                    ateks=round(a[0]*10,2)    
                    tex='%.2f' % ateks + 'mm/10god'
                    lab=lab+ ', ' + tex
                    
                    B = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trendb_yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(B.variables.keys())
                    b=B.variables['pr'][:]
                    b=b.flatten()
                    
                    #---Crtanje
                    crtajniz(ax[g,v], var=pr, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=None)#, yLim=yLim)
                
                
                
                elif v==1:
                    yLab='Temperatura [\N{DEGREE SIGN}C]'
                    
                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi podaci zove se yearsum_yearmean, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/yearsum_yearmean/CN/tas_45/yearmean_monmean_STATION_1_CN_tas_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/yearsum_yearmean/{}/{}_{}/yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))                    
                    tas=nc.variables['tas'][:] #2m mean temperature [C]
                    tas=tas.flatten()
                    
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/tas_45/trenda_yearmean_monmean_STATION_1_CN_tas_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['tas'][:]
                    a=a.flatten()
                    ateks=round(a[0]*10,2)
                    tex='%.2f' % ateks + '\N{DEGREE SIGN}C/10god'
                                       
                    B = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trendb_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(B.variables.keys())
                    b=B.variables['tas'][:]
                    b=b.flatten()

                    #---Crtanje
                    crtajniz(ax[g,v], var=tas, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=tex)#, yLim=yLim)
    
    
    #---Spremanje slika
    #fig.savefig('{}.png'.format(MARK[i-1]))

# %%
#----CRTANJE VREMENSKIH NIZOVA SREDNJIH MINIMALNIH I MAKSIMALNIH GODIŠNJIH TEMPERATURA (TASMAX, TASMIN) ZA SVAKU POSTAJU

from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap


#---Definiram funkciju za crtanje
def crtajniz(ax,var,yLab,tit,color,linewidth,lab,a,b,tex):#,yLim):
    x=np.arange(1971,2072)
    ax.plot(x,var,color=color,linewidth=linewidth,label=lab)
    
    x_pom=np.arange(0,101)
    y=(a*x_pom)+b
    ax.plot(x,y,color=color,linewidth=linewidth)
    
    ax.set_xticks(np.arange(1970,2072,5))
    ax.set_xticklabels(np.arange(1970,2072,5), fontsize=17)# Rotation=90.
    ax.set_xlim([1970,2072])
    ax.set_xlabel('Godina', fontsize=20)
    ax.text(2071, a*100+b, tex, color=color, fontsize=17)

    ax.set_ylabel(yLab, fontsize=20)
    ytlabs=ax.get_yticks()
    ytlabs = [int(x) for x in ytlabs]
    ax.set_yticklabels(ytlabs,fontsize=17)
    #ax.set_ylim(yLim)
    
    ax.set_title(tit, fontsize=22)
    ax.legend(fontsize='xx-large')
    ax.grid(b=True)
    return


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['tasmax','tasmin'] #VAR[v]
SCEN=['45','85'] #SCEN[s]

#---Dobavljam datoteke

for i in np.arange(1,22): #petlja po stanicama
    fig, ax=plt.subplots(4,2, figsize=(45,30))
    fig.subplots_adjust(top=0.96,bottom=0.09)
    fig.suptitle(MARK[i-1],fontsize=27)
    
    for g in np.arange(0,4): #petlja po GCM
                
        for v in np.arange(0,2): #petlja po VAR
            yLab='Temperatura [\N{DEGREE SIGN}C]'
            tit=GCM[g]+' '+VAR[v]                        
                    
            for s in np.arange(0,2): #petlja po scenarijima
                
                if s==0:
                    lab='RCM 4.5'
                    color='blue' #RCP 4.5 podatke crtati ću plavom linijom
                    linewidth=2;
                elif s==1:
                    lab='RCM 8.5'
                    color='red'; #RCP 8.5 podatke crtati ću crvenom linijom
                    linewidth=2.5; 
                
                if v==0:
                    
                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi podaci zove se yearsum_yearmean, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/yearsum_yearmean/CN/tasmax_85/yearmean_monmean_STATION_1_CN_tasmax_85.nc
                    nc = NetCDFFile('C:/--PRAKSA--/yearsum_yearmean/{}/{}_{}/yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    tasmax = nc.variables['tasmax'][:] #2m mean maximum temperature [C]
                    tasmax=tasmax.flatten()
                    
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/tasmax_45/trenda_yearmean_monmean_STATION_1_CN_tasmax_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['tasmax'][:]
                    a=a.flatten()
                    ateks=round(a[0]*10,2)    
                    tex='%.2f' % ateks + '\N{DEGREE SIGN}C/10god'
                                      
                    B = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trendb_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(B.variables.keys())
                    b=B.variables['tasmax'][:]
                    b=b.flatten()
                    
                    #---Crtanje
                    crtajniz(ax[g,v], var=tasmax, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=tex)#, yLim=yLim)
                
                
                
                elif v==1:
                    
                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi podaci zove se yearsum_yearmean, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/yearsum_yearmean/CN/tasmin_45/yearmean_monmean_STATION_1_CN_tasmin_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/yearsum_yearmean/{}/{}_{}/yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))                    
                    tasmin=nc.variables['tasmin'][:] #2m mean minimum temperature [C]
                    tasmin=tasmin.flatten()
                    
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/tas_45/trenda_yearmean_monmean_STATION_1_CN_tas_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['tasmin'][:]
                    a=a.flatten()
                    ateks=round(a[0]*10,2)
                    tex='%.2f' % ateks + '\N{DEGREE SIGN}C/10god'
                                       
                    B = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trendb_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(B.variables.keys())
                    b=B.variables['tasmin'][:]
                    b=b.flatten()

                    #---Crtanje
                    crtajniz(ax[g,v], var=tasmin, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=tex)#, yLim=yLim)
    
    
    #---Spremanje slika
    #fig.savefig('{}.png'.format(MARK[i-1]))

# %%
#---CRTANJE KARTE HRVATSKE SA UCRTANIM TRENDOVIMA ZA PR I TAS
from netCDF4 import Dataset as NetCDFFile 
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt



LON=np.zeros(21)
LAT=np.zeros(21)
MARK=[' ']*21 #An empty list of strings containing 21 elements

LON[0]=14.3166654 ; LAT[0]=45.3499986; MARK[0]='Volosko'
LON[1]=15.966568 ; LAT[1]=45.815399; MARK[1]='Zagreb'
LON[2]=15.87889 ; LAT[2]=46.16083; MARK[2]='Krapina'

LON[3]=16.37833 ; LAT[3]=45.46611; MARK[3]='Sisak'
LON[4]=15.54778 ; LAT[4]=45.48722; MARK[4]='Karlovac'
LON[5]=16.33778 ; LAT[5]=46.30444; MARK[5]='Varaždin'

LON[6]=16.8275 ; LAT[6]=46.16278; MARK[6]='Koprivnica'
LON[7]=16.84889 ; LAT[7]=45.89861; MARK[7]='Bjelovar'
LON[8]=14.40917 ; LAT[8]=45.34306; MARK[8]='Rijeka'

LON[9]=16.43915 ; LAT[9]=43.50891; MARK[9]='Split'
LON[10]=13.93667 ; LAT[10]=45.24028; MARK[10]='Pazin'
LON[11]=15.37472 ; LAT[11]=44.54611; MARK[11]='Gospić'

LON[12]=17.38389 ; LAT[12]=45.83194; MARK[12]='Virovitica'
LON[13]=17.68528 ; LAT[13]=45.34028; MARK[13]='Požega'
LON[14]=18.01556 ; LAT[14]=45.16028; MARK[14]='Slavonski Brod'

LON[15]=15.24222 ; LAT[15]=44.11972; MARK[15]='Zadar'
LON[16]=18.69389 ; LAT[16]=45.55111; MARK[16]='Osijek'
LON[17]=15.90583 ; LAT[17]=43.72722; MARK[17]='Šibenik'

LON[18]=18.99972 ; LAT[18]=45.34333; MARK[18]='Vukovar'
LON[19]=18.09216 ; LAT[19]=42.64807; MARK[19]='Dubrovnik'
LON[20]=16.43389 ; LAT[20]=46.38444; MARK[20]='Čakovec'


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['pr','tas'] #VAR[v]
SCEN=['45','85'] #SCEN[s]


for s in np.arange (0,2):
    for v in np.arange(0,2):
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(25,29))
        #fig.subplots_adjust(top=0.96,bottom=0.09)
        fig.subplots_adjust(left=None, bottom=0.29, right=None, top=0.96, wspace=None, hspace=0.)
        fig.suptitle('   '+VAR[v]+ '_'+SCEN[s],fontsize=30)          

        for ax in axes.flat:
            if ax==axes.flat[0]:
                g=0
            elif ax==axes.flat[1]:
                g=1
            elif ax==axes.flat[2]:
                g=2
            elif ax==axes.flat[3]:
                g=3
            
            map_ax = Basemap(ax=ax, llcrnrlon=13.2, llcrnrlat=42.2, urcrnrlon=19.6,
                   urcrnrlat=46.6, projection='lcc', lat_0=44.4, lon_0=16.3, resolution='f')
            #Draw land/ocean/lake mask, coastlines and country borders
            map_ax.drawlsmask(land_color='white', ocean_color='white', lakes=True)
            map_ax.drawcoastlines()
            map_ax.drawcountries(color='black')

            #Draw parallels and meridians
            map_ax.drawparallels(np.arange(42,47,1),labels=[True,False,False,False],linewidth=0)               
            map_ax.drawmeridians(np.arange(13,20,1),labels=[0,0,0,1],rotation=90.,linewidth=0)

            
                
            for i in np.arange(1,22,1): #petlja po postajama, postaja na i-toj poziciji se zove MARK[i-1]
                
                if v==0:
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/pr_45/trenda_yearsum_monsum_STATION_1_CN_pr_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['pr'][:]
                    a=a.flatten()
                    a=a[0]*10
                    
                    if abs(a)<=1:
                        markersize=3
                        #lab='|trend| <= 1 mm/10god'
                    if abs(a)>1 and abs(a)<=5:
                        markersize=7
                        #lab='1 < |trend| <= 5 mm/10god'
                    if abs(a)>5 and abs(a)<=10:
                        markersize=11
                        #lab='5 < |trend| <= 10 mm/10god'
                    if abs(a)>10 and abs(a)<=15:
                        markersize=15
                        #lab='10 < |trend| <= 15 mm/10god'
                    if abs(a)>15 and abs(a)<=20:
                        markersize=19
                        #lab='15 < |trend| <= 20 mm/10god'
                    if abs(a)>20 and abs(a)<=25:
                        markersize=23
                        #lab='20 < |trend| <= 25 mm/10god'
                    if abs(a)>25:
                        markersize=27
                        #lab='|trend| > 25 mm/10god'
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange'
                                                                
                if v==1:
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/tas_45/trenda_yearmean_monmean_STATION_1_CN_tas_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['tas'][:]
                    a=a.flatten()
                    a=a[0]*10
                    
                   
                    if abs(a)<=0.1:
                        markersize=3
                    if abs(a)>0.1 and abs(a)<=0.2:
                        markersize=8
                    if abs(a)>0.2 and abs(a)<=0.3:
                        markersize=13
                    if abs(a)>0.3 and abs(a)<=0.4:
                        markersize=18
                    if abs(a)>0.4 and abs(a)<=0.5:
                        markersize=23
                    if abs(a)>0.5:
                        markersize=28
                    
                    #Obzirom da temperatura svugdje ima pozitivan trend ne moram gledati njenu apsolutnu vrijednost, a>0 uvijek!
                    if a<0:
                        color='blue'
                    if a>0:
                        color='red'
                        
                        
                    
                
                x, y = map_ax(LON[i-1], LAT[i-1])
                ime=MARK[i-1]
                        
                tit=GCM[g]
                #ax= plt.gca() #Get current axes
                ax.plot(x, y, color=color, marker='o', markersize=markersize) #Scattering, plotting markers as red dots
                ax.text(x+2000, y+2000, ime, fontsize=14) #Plotting text next to the points (2000 (x) & 2000 (y) points away from the marker)            

    
                ax.set_title(tit, fontsize=20)
    
                #Crtanje legende
                if v==0:
                    x0=13.5; y0=44.8; korak=21000; jmax=27; jmin=3
                    xx,yy=map_ax(x0,y0)
                    lab=['< -25 mm/10god','-20 - -25 mm/10god','-15 - -20 mm/10god','-10 - -15 mm/10god','-5 - -10 mm/10god','-1 - -5 mm/10god','0 - -1 mm/10god','0 - 1 mm/10god','1 - 5 mm/10god','5 - 10 mm/10god','10 - 15 mm/10god','15 - 20 mm/10god','20 - 25 mm/10god','> 25 mm/10god']
    
                    j=jmax
                    for i in np.arange(0,7):
                        ax.plot([xx], [yy-i*korak],'o', color='orange', markersize=j)
                        j=j-4

                    j=jmin
                    for i in np.arange(7,14):
                        ax.plot([xx], [yy-i*korak],'o', color='cyan', markersize=j)
                        j=j+4

                    for i in np.arange(0,14):
                        ax.annotate(lab[i], xy=(xx,yy-i*korak), xytext=(xx+korak,yy-i*korak))
    
    
                elif v==1:
                    x0=13.5; y0=43.5; korak=23000; jmax=28; jmin=3
                    xx,yy=map_ax(x0,y0)
                    lab=['<= 0.1 \N{DEGREE SIGN}C/10god','0.1 - 0.2 \N{DEGREE SIGN}C/10god','0.2 - 0.3 \N{DEGREE SIGN}C/10god', '0.3 - 0.4 \N{DEGREE SIGN}C/10god', '0.4 - 0.5 \N{DEGREE SIGN}C/10god', '> 0.5 \N{DEGREE SIGN}C/10god']
    
                    #Napravila sam samo dio kada je trend temperature pozitivan jer to vrijedi u svim slučajevima
                    j=jmin
                    for i in np.arange(0,6):
                        ax.plot([xx], [yy-i*korak],'o', color='red', markersize=j)
                        ax.annotate(lab[i], xy=(xx,yy-i*korak), xytext=(xx+korak,yy-i*korak))
                        j=j+5
        
    
        #---Spremanje slika
        #fig.savefig('{}_{}.png'.format(VAR[v],SCEN[s]))           
        plt.show()

# %%
#---CRTANJE KARTE HRVATSKE SA UCRTANIM TRENDOVIMA ZA TASMIN I TASMAX
from netCDF4 import Dataset as NetCDFFile 
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

LON=np.zeros(21)
LAT=np.zeros(21)
MARK=[' ']*21 #An empty list of strings containing 21 elements

LON[0]=14.3166654 ; LAT[0]=45.3499986; MARK[0]='Volosko'
LON[1]=15.966568 ; LAT[1]=45.815399; MARK[1]='Zagreb'
LON[2]=15.87889 ; LAT[2]=46.16083; MARK[2]='Krapina'

LON[3]=16.37833 ; LAT[3]=45.46611; MARK[3]='Sisak'
LON[4]=15.54778 ; LAT[4]=45.48722; MARK[4]='Karlovac'
LON[5]=16.33778 ; LAT[5]=46.30444; MARK[5]='Varaždin'

LON[6]=16.8275 ; LAT[6]=46.16278; MARK[6]='Koprivnica'
LON[7]=16.84889 ; LAT[7]=45.89861; MARK[7]='Bjelovar'
LON[8]=14.40917 ; LAT[8]=45.34306; MARK[8]='Rijeka'

LON[9]=16.43915 ; LAT[9]=43.50891; MARK[9]='Split'
LON[10]=13.93667 ; LAT[10]=45.24028; MARK[10]='Pazin'
LON[11]=15.37472 ; LAT[11]=44.54611; MARK[11]='Gospić'

LON[12]=17.38389 ; LAT[12]=45.83194; MARK[12]='Virovitica'
LON[13]=17.68528 ; LAT[13]=45.34028; MARK[13]='Požega'
LON[14]=18.01556 ; LAT[14]=45.16028; MARK[14]='Slavonski Brod'

LON[15]=15.24222 ; LAT[15]=44.11972; MARK[15]='Zadar'
LON[16]=18.69389 ; LAT[16]=45.55111; MARK[16]='Osijek'
LON[17]=15.90583 ; LAT[17]=43.72722; MARK[17]='Šibenik'

LON[18]=18.99972 ; LAT[18]=45.34333; MARK[18]='Vukovar'
LON[19]=18.09216 ; LAT[19]=42.64807; MARK[19]='Dubrovnik'
LON[20]=16.43389 ; LAT[20]=46.38444; MARK[20]='Čakovec'


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
VAR=['tasmin','tasmax'] #VAR[v]
SCEN=['45','85'] #SCEN[s]


for s in np.arange (0,2):
    for v in np.arange(0,2):
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(19,23))
        #fig.subplots_adjust(top=0.96,bottom=0.09)
        fig.subplots_adjust(left=None, bottom=0.29, right=None, top=0.96, wspace=None, hspace=0.)
        fig.suptitle('   '+VAR[v]+ '_'+SCEN[s],fontsize=30)          

        for ax in axes.flat:
            if ax==axes.flat[0]:
                g=0
            elif ax==axes.flat[1]:
                g=1
            elif ax==axes.flat[2]:
                g=2
            elif ax==axes.flat[3]:
                g=3
            
            map_ax = Basemap(ax=ax, llcrnrlon=13.2, llcrnrlat=42.2, urcrnrlon=19.6,
                   urcrnrlat=46.6, projection='lcc', lat_0=44.4, lon_0=16.3, resolution='f')
            #Draw land/ocean/lake mask, coastlines and country borders
            map_ax.drawlsmask(land_color='white', ocean_color='white', lakes=True)
            map_ax.drawcoastlines()
            map_ax.drawcountries(color='black')

            #Draw parallels and meridians
            map_ax.drawparallels(np.arange(42,47,1),labels=[True,False,False,False],linewidth=0)               
            map_ax.drawmeridians(np.arange(13,20,1),labels=[0,0,0,1],rotation=90.,linewidth=0)

            
                
            for i in np.arange(1,22,1): #petlja po postajama, postaja na i-toj poziciji se zove MARK[i-1]
                
                #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                #C:/--PRAKSA--/trend/CN/tas_45/trenda_yearmean_monmean_STATION_1_CN_tas_45.nc
                A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearmean_monmean_STATION_{}_{}_{}_{}.nc'.format(GCM[g],VAR[v],SCEN[s],i,GCM[g],VAR[v],SCEN[s]))
                #print(A.variables.keys())
                if v==0:
                    a=A.variables['tasmin'][:]
                if v==1:
                    a=A.variables['tasmax'][:]
                a=a.flatten()
                a=a[0]*10
                if abs(a)<=0.1:
                    markersize=3
                if abs(a)>0.1 and abs(a)<=0.2:
                    markersize=8
                if abs(a)>0.2 and abs(a)<=0.3:
                    markersize=13
                if abs(a)>0.3 and abs(a)<=0.4:
                    markersize=18
                if abs(a)>0.4 and abs(a)<=0.5:
                    markersize=23
                if abs(a)>0.5:
                    markersize=28
                    
                #Obzirom da temperatura svugdje ima pozitivan trend ne moram gledati njenu apsolutnu vrijednost, a>0 uvijek!
                if a<0:
                    color='blue'
                if a>0:
                    color='red'
                    
                
                x, y = map_ax(LON[i-1], LAT[i-1])
                ime=MARK[i-1]
                        
                tit=GCM[g]
                #ax= plt.gca() #Get current axes
                ax.plot(x, y, color=color, marker='o', markersize=markersize) #Scattering, plotting markers as red dots
                ax.text(x+2000, y+2000, ime, fontsize=12) #Plotting text next to the points (2000 (x) & 2000 (y) points away from the marker)            

    
                ax.set_title(tit, fontsize=20)
    
                #Crtanje legende
                x0=13.5; y0=43.7; korak=29000; jmax=28; jmin=3
                xx,yy=map_ax(x0,y0)
                lab=['<= 0.1 \N{DEGREE SIGN}C/10god','0.1 - 0.2 \N{DEGREE SIGN}C/10god','0.2 - 0.3 \N{DEGREE SIGN}C/10god', '0.3 - 0.4 \N{DEGREE SIGN}C/10god', '0.4 - 0.5 \N{DEGREE SIGN}C/10god', '> 0.5 \N{DEGREE SIGN}C/10god']
    
                #Napravila sam samo dio kada je trend temperature pozitivan jer to vrijedi u svim slučajevima
                j=jmin
                for i in np.arange(0,6):
                    ax.plot([xx], [yy-i*korak],'o', color='red', markersize=j)
                    ax.annotate(lab[i], xy=(xx,yy-i*korak), xytext=(xx+korak,yy-i*korak))
                    j=j+5
        #---Spremanje slika
        #fig.savefig('{}_{}.png'.format(VAR[v],SCEN[s])) 
                   
        plt.show()

# %%
#----CRTANJE VREMENSKIH NIZOVA INDEKSA ZA PR I TAS I NJIHOVIH TRENDOVA

from netCDF4 import Dataset as NetCDFFile 
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap

#---Definiram funkciju za crtanje
def crtajniz(ax,var,yLab,tit,color,linewidth,lab,a,b,tex):#,yLim):
          
    x=np.arange(1971,2072)
    ax.plot(x,var,color=color,linewidth=linewidth,label=lab)
    
    x_pom=np.arange(0,101)
    y=(a*x_pom)+b
    ax.plot(x,y,color=color,linewidth=linewidth)
    
    ax.set_xticks(np.arange(1970,2072,5))
    ax.set_xticklabels(np.arange(1970,2072,5), fontsize=17)# Rotation=90.
    ax.set_xlim([1970,2072])
    ax.set_xlabel('Godina', fontsize=20)
    ax.text(2071, a*100+b, tex, color=color, fontsize=17)

    ax.set_ylabel(yLab, fontsize=20)
    ytlabs=ax.get_yticks()
    ytlabs = [int(x) for x in ytlabs]
    ax.set_yticklabels(ytlabs,fontsize=17)
    #ax.set_ylim(yLim)
    
    ax.set_title(tit, fontsize=22)
    ax.legend(fontsize='xx-large')
    ax.grid(b=True)
    return


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
IND=['Rx1day','Rx5day','SDII','R10mm','R20mm','pr'] #IND[i]
SCEN=['45','85'] #SCEN[s]


#---Dobavljam datoteke

for j in np.arange(1,22): #petlja po stanicama

    
    for g in np.arange(0,4): #petlja po GCM
        fig, ax=plt.subplots(3,2, figsize=(45,30))
        fig.subplots_adjust(top=0.96,bottom=0.09)
        fig.suptitle('   '+MARK[j-1]+ ', '+GCM[g],fontsize=35)
                
        for i in np.arange(0,6): #petlja po IND
            tit=IND[i]
                                                   
            for s in np.arange(0,2): #petlja po scenarijima
                
                if s==0:
                    lab='RCM 4.5'
                    color='blue' #RCP 4.5 podatke crtati ću plavom linijom
                    linewidth=2;
                elif s==1:
                    lab='RCM 8.5'
                    color='red'; #RCP 8.5 podatke crtati ću crvenom linijom
                    linewidth=2.5; 
                    
                
                if i<5:
                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi indeksi zove se indeksi, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/indeksi/Rx1day/konacno/CN/pr_45/STATION_1_CN_pr_45.nc
                    nc = NetCDFFile('C:/--PRAKSA--/indeksi/{}/konacno/{}/pr_{}/STATION_{}_{}_pr_{}.nc'.format(IND[i],GCM[g],SCEN[s],j,GCM[g],SCEN[s]))
            
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se indeksi_trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/indeksi_trend/CN/Rx1day/pr_45/trenda_STATION_1_CN_pr_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/indeksi_trend/{}/{}/pr_{}/trenda_STATION_{}_{}_pr_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],SCEN[s]))
                    #print(A.variables.keys())                     
                    B = NetCDFFile('C:/--PRAKSA--/indeksi_trend/{}/{}/pr_{}/trendb_STATION_{}_{}_pr_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],SCEN[s]))                #print(B.variables.keys())              
    
                
                    if i==0:
                        indeks = nc.variables['highest_one_day_precipitation_amount_per_time_period'][:]                     
                        yLab=IND[i]+' '+'[mm]'
                        a=A.variables['highest_one_day_precipitation_amount_per_time_period'][:]
                        a=a.flatten()
                        ateks=round(a[0]*10,2)    
                        tex='%.2f' % ateks + 'mm/10god'
                        lab=lab+ ', ' + tex
                        b=B.variables['highest_one_day_precipitation_amount_per_time_period'][:]
                        c=0;d=0
                    
                    if i==1:
                        indeks = nc.variables['highest_five_day_precipitation_amount_per_time_period'][:]                     
                        yLab=IND[i]+' '+'[mm]'
                        a=A.variables['highest_five_day_precipitation_amount_per_time_period'][:]
                        a=a.flatten()
                        ateks=round(a[0]*10,2)    
                        tex='%.2f' % ateks + 'mm/10god'
                        lab=lab+ ', ' + tex
                        b=B.variables['highest_five_day_precipitation_amount_per_time_period'][:]
                        c=0;d=1
                    
                    if i==2:
                        indeks = nc.variables['simple_daily_intensity_index_per_time_period'][:]                     
                        yLab=IND[i]+' '+'[mm]'
                        a=A.variables['simple_daily_intensity_index_per_time_period'][:]
                        a=a.flatten()
                        ateks=round(a[0]*10,2)    
                        tex='%.2f' % ateks + 'mm/10god'
                        lab=lab+ ', ' + tex
                        b=B.variables['simple_daily_intensity_index_per_time_period'][:]
                        c=2;d=0
                    
                    if i==3:
                        indeks = nc.variables['heavy_precipitation_days_index_per_time_period'][:] 
                        yLab=IND[i]+' '+'[Number of days]'
                        a=A.variables['heavy_precipitation_days_index_per_time_period'][:]
                        a=a.flatten()
                        ateks=round(a[0]*10,2)    
                        tex='%.2f' % ateks + 'Number of days/10god'
                        lab=lab+ ', ' + tex
                        b=B.variables['heavy_precipitation_days_index_per_time_period'][:]
                        c=1;d=0
                    
                    if i==4:
                        indeks = nc.variables['very_heavy_precipitation_days_index_per_time_period'][:]                     
                        yLab=IND[i]+' '+'[Number of days]'
                        a=A.variables['very_heavy_precipitation_days_index_per_time_period'][:]
                        a=a.flatten()
                        ateks=round(a[0]*10,2)    
                        tex='%.2f' % ateks + 'Number of days/10god'
                        lab=lab+ ', ' + tex
                        b=B.variables['very_heavy_precipitation_days_index_per_time_period'][:]
                        c=1;d=1
                        
                    indeks=indeks.flatten()
                    b=b.flatten()
                    #---Crtanje
                    crtajniz(ax=ax[c,d], var=indeks, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=None)#, yLim=yLim)
                    
                    #Namještanje istih y osi za prvi red 
                    ax[0,0].get_shared_y_axes().join(ax[0,0], ax[0,1])
                    ytlabs=ax[0,1].get_yticks()
                    ax[0,0].set_yticklabels(ytlabs)
                    
                    #Namještanje istih y osi za drugi red
                    ax[1,0].get_shared_y_axes().join(ax[1,0], ax[1,1])
                    ytlabs=ax[1,1].get_yticks()
                    ax[1,0].set_yticklabels(ytlabs)
                    
                
                    
                elif i==5:
                    yLab='Oborina [mm]'
                    
                    #---Podaci za crtanje vremenskog niza
                    #Folder u kojem se nalaze svi podaci zove se yearsum_yearmean, a path originalno izgleda npr ovako:
                    #C:/--PRAKSA--/yearsum_yearmean/CN/pr_85/yearsum_monsum_STATION_1_CN_pr_85.nc
                    nc = NetCDFFile('C:/--PRAKSA--/yearsum_yearmean/{}/{}_{}/yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],IND[i],SCEN[s]))
                    pr = nc.variables['pr'][:] #precipitation [mm]
                    pr=pr.flatten()
                    
                    #---Podaci za crtanje pravca linearne regresije
                    #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                    #C:/--PRAKSA--/trend/CN/pr_45/trenda_yearsum_monsum_STATION_1_CN_pr_45.nc
                    A = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trenda_yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],IND[i],SCEN[s]))
                    #print(A.variables.keys())
                    a=A.variables['pr'][:]
                    a=a.flatten()
                    ateks=round(a[0]*10,2)    
                    tex='%.2f' % ateks + 'mm/10god'
                    lab=lab+ ', ' + tex
                    
                    B = NetCDFFile('C:/--PRAKSA--/trend/{}/{}_{}/trendb_yearsum_monsum_STATION_{}_{}_{}_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],IND[i],SCEN[s]))
                    #print(B.variables.keys())
                    b=B.variables['pr'][:]
                    b=b.flatten()
                     
                    c=2;d=1    
                    #---Crtanje
                    crtajniz(ax=ax[c,d], var=pr, yLab=yLab, tit=tit, color=color, linewidth=linewidth, lab=lab, a=a[0], b=b[0], tex=None)#, yLim=yLim)
                
                
        #fig.savefig('{}_{}.png'.format(MARK[j-1],GCM[g]))

# %%
#---CRTANJE KARTE HRVATSKE SA UCRTANIM TRENDOVIMA INDEKSA ZA PR

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset as NetCDFFile 
import numpy as np


LON=np.zeros(21)
LAT=np.zeros(21)
MARK=[' ']*21 #An empty list of strings containing 21 elements

LON[0]=14.3166654 ; LAT[0]=45.3499986; MARK[0]='Volosko'
LON[1]=15.966568 ; LAT[1]=45.815399; MARK[1]='Zagreb'
LON[2]=15.87889 ; LAT[2]=46.16083; MARK[2]='Krapina'

LON[3]=16.37833 ; LAT[3]=45.46611; MARK[3]='Sisak'
LON[4]=15.54778 ; LAT[4]=45.48722; MARK[4]='Karlovac'
LON[5]=16.33778 ; LAT[5]=46.30444; MARK[5]='Varaždin'

LON[6]=16.8275 ; LAT[6]=46.16278; MARK[6]='Koprivnica'
LON[7]=16.84889 ; LAT[7]=45.89861; MARK[7]='Bjelovar'
LON[8]=14.40917 ; LAT[8]=45.34306; MARK[8]='Rijeka'

LON[9]=16.43915 ; LAT[9]=43.50891; MARK[9]='Split'
LON[10]=13.93667 ; LAT[10]=45.24028; MARK[10]='Pazin'
LON[11]=15.37472 ; LAT[11]=44.54611; MARK[11]='Gospić'

LON[12]=17.38389 ; LAT[12]=45.83194; MARK[12]='Virovitica'
LON[13]=17.68528 ; LAT[13]=45.34028; MARK[13]='Požega'
LON[14]=18.01556 ; LAT[14]=45.16028; MARK[14]='Slavonski Brod'

LON[15]=15.24222 ; LAT[15]=44.11972; MARK[15]='Zadar'
LON[16]=18.69389 ; LAT[16]=45.55111; MARK[16]='Osijek'
LON[17]=15.90583 ; LAT[17]=43.72722; MARK[17]='Šibenik'

LON[18]=18.99972 ; LAT[18]=45.34333; MARK[18]='Vukovar'
LON[19]=18.09216 ; LAT[19]=42.64807; MARK[19]='Dubrovnik'
LON[20]=16.43389 ; LAT[20]=46.38444; MARK[20]='Čakovec'


GCM=['CN', 'EC', 'HA', 'MP'] #GCM[g]
#VAR='pr'
SCEN=['45','85'] #SCEN[s]
IND=['Rx1day','Rx5day','R10mm','R20mm','SDII'] #IND[i]


for s in np.arange (0,2):
    for i in np.arange(0,5):
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(25,29))
        #fig.subplots_adjust(top=0.96,bottom=0.09)
        fig.subplots_adjust(left=None, bottom=0.29, right=None, top=0.96, wspace=None, hspace=0.)
        fig.suptitle('   '+IND[i]+ '_'+SCEN[s],fontsize=30)          

        for ax in axes.flat:
            if ax==axes.flat[0]:
                g=0
            elif ax==axes.flat[1]:
                g=1
            elif ax==axes.flat[2]:
                g=2
            elif ax==axes.flat[3]:
                g=3
            
            map_ax = Basemap(ax=ax, llcrnrlon=13.2, llcrnrlat=42.2, urcrnrlon=19.6,
                   urcrnrlat=46.6, projection='lcc', lat_0=44.4, lon_0=16.3, resolution='f')
            #Draw land/ocean/lake mask, coastlines and country borders
            map_ax.drawlsmask(land_color='white', ocean_color='white', lakes=True)
            map_ax.drawcoastlines()
            map_ax.drawcountries(color='black')

            #Draw parallels and meridians
            map_ax.drawparallels(np.arange(42,47,1),labels=[True,False,False,False],linewidth=0)               
            map_ax.drawmeridians(np.arange(13,20,1),labels=[0,0,0,1],rotation=90.,linewidth=0)

            
                
            for j in np.arange(1,22,1): #petlja po postajama, postaja na j-toj poziciji se zove MARK[j-1]
                
                
                #Folder u kojem se nalaze komponente linearne regresije a i b zove se trend, a path originalno izgleda npr. ovako:
                #C:/--PRAKSA--/indeksi_trend/CN/Rx1day/pr_45/trenda_STATION_1_CN_pr_45.nc
                A = NetCDFFile('C:/--PRAKSA--/indeksi_trend/{}/{}/pr_{}/trenda_STATION_{}_{}_pr_{}.nc'.format(GCM[g],IND[i],SCEN[s],j,GCM[g],SCEN[s]))
                if i==0:
                    a=A.variables['highest_one_day_precipitation_amount_per_time_period'][:]
                    a=a.flatten()
                    a=a[0]*10
                    
                    if abs(a)<=0.2:
                        markersize=3
                    
                    elif abs(a)>0.2 and abs(a)<=0.5:
                        markersize=7
                        
                    elif abs(a)>0.5 and abs(a)<=0.8:
                        markersize=11
                        
                    elif abs(a)>0.8 and abs(a)<=1.1:
                        markersize=15
                        
                    elif abs(a)>1.1 and abs(a)<=1.3:
                        markersize=19
                        
                    elif abs(a)>1.3 and abs(a)<=1.6:
                        markersize=23
                        
                    elif abs(a)>1.6:
                        markersize=27
                        
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange'
                    
                elif i==1:
                    a=A.variables['highest_five_day_precipitation_amount_per_time_period'][:]
                    a=a.flatten()
                    a=a[0]*10
                                        
                    if abs(a)<=0.2:
                        markersize=3
                    
                    elif abs(a)>0.2 and abs(a)<=0.5:
                        markersize=7
                        
                    elif abs(a)>0.5 and abs(a)<=0.8:
                        markersize=11
                        
                    elif abs(a)>0.8 and abs(a)<=1.1:
                        markersize=15
                        
                    elif abs(a)>1.1 and abs(a)<=1.3:
                        markersize=19
                        
                    elif abs(a)>1.3 and abs(a)<=1.6:
                        markersize=23
                        
                    elif abs(a)>1.6:
                        markersize=27
                        
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange'
                    
                    
                elif i==2:
                    a=A.variables['heavy_precipitation_days_index_per_time_period'][:]
                    a=a.flatten()
                    a=a[0]*10
                    
                    if abs(a)<=0.1:
                        markersize=3
                    
                    elif abs(a)>0.1 and abs(a)<=0.3:
                        markersize=7
                        
                    elif abs(a)>0.3 and abs(a)<=0.5:
                        markersize=11
                        
                    elif abs(a)>0.5 and abs(a)<=0.7:
                        markersize=15
                        
                    elif abs(a)>0.7 and abs(a)<=0.9:
                        markersize=19
                        
                    elif abs(a)>0.9 and abs(a)<=1.1:
                        markersize=23
                        
                    elif abs(a)>1.1:
                        markersize=27
                        
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange'  
                    
                    
                elif i==3:
                    a=A.variables['very_heavy_precipitation_days_index_per_time_period'][:]
                    a=a.flatten()
                    a=a[0]*10
                    
                    if abs(a)<=0.1:
                        markersize=3
                    
                    elif abs(a)>0.1 and abs(a)<=0.3:
                        markersize=7
                        
                    elif abs(a)>0.3 and abs(a)<=0.5:
                        markersize=11
                        
                    elif abs(a)>0.5 and abs(a)<=0.7:
                        markersize=15
                        
                    elif abs(a)>0.7 and abs(a)<=0.9:
                        markersize=19
                        
                    elif abs(a)>0.9 and abs(a)<=1.1:
                        markersize=23
                        
                    elif abs(a)>1.1:
                        markersize=27
                        
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange' 
                    
                    
                elif i==4:
                    a=A.variables['simple_daily_intensity_index_per_time_period'][:]
                    a=a.flatten()
                    a=a[0]*10
                                    
                    if abs(a)<=0.02:
                        markersize=3
                    
                    elif abs(a)>0.02 and abs(a)<=0.04:
                        markersize=7
                        
                    elif abs(a)>0.04 and abs(a)<=0.06:
                        markersize=11
                        
                    elif abs(a)>0.06 and abs(a)<=0.08:
                        markersize=15
                        
                    elif abs(a)>0.08 and abs(a)<=0.1:
                        markersize=19
                        
                    elif abs(a)>0.1 and abs(a)<=0.12:
                        markersize=23
                        
                    elif abs(a)>0.12:
                        markersize=27
                        
            
                    if a>0:
                        color='cyan'
                    elif a<0:
                        color='orange'    

                                                                
                        
                                    
                
                x, y = map_ax(LON[j-1], LAT[j-1])
                ime=MARK[j-1]
                        
                tit=GCM[g]
                #ax= plt.gca() #Get current axes
                ax.plot(x, y, color=color, marker='o', markersize=markersize) #Scattering, plotting markers as red dots
                ax.text(x+2000, y+2000, ime, fontsize=14) #Plotting text next to the points (2000 (x) & 2000 (y) points away from the marker)            

    
                ax.set_title(tit, fontsize=20)
    
                #Crtanje legende
                if i==0 or i==1:
                    x0=13.5; y0=44.8; korak=21000; mmax=27; mmin=3
                    xx,yy=map_ax(x0,y0)
                    lab=['< -1.6 mm/10god','-1.3 - -1.6 mm/10god','-1.1 - -1.3 mm/10god','-0.8 - -1.1 mm/10god','-0.5 - -0.8 mm/10god','-0.2 - -0.5 mm/10god','0 - -0.2 mm/10god','0 - 0.2 mm/10god','0.2 - 0.5 mm/10god','0.5 - 0.8 mm/10god','0.8 - 1.1 mm/10god','1.1 - 1.3 mm/10god','1.3 - 1.6 mm/10god','> 1.6 mm/10god']
    
                    m=mmax
                    for k in np.arange(0,7):
                        ax.plot([xx], [yy-k*korak],'o', color='orange', markersize=m)
                        m=m-4

                    m=mmin
                    for k in np.arange(7,14):
                        ax.plot([xx], [yy-k*korak],'o', color='cyan', markersize=m)
                        m=m+4

                    for k in np.arange(0,14):
                        ax.annotate(lab[k], xy=(xx,yy-k*korak), xytext=(xx+korak,yy-k*korak))
                        
                elif i==2 or i==3:
                    x0=13.5; y0=44.8; korak=21000; mmax=27; mmin=3
                    xx,yy=map_ax(x0,y0)
                    lab=['< -1.1 dan/10god','-0.9 - -1.1 dan/10god','-0.7 - -0.9 dan/10god','-0.5 - -0.7 dan/10god','-0.3 - -0.5 dan/10god','-0.1 - -0.3 dan/10god','0 - -0.1 dan/10god','0 - 0.1 dan/10god','0.1 - 0.3 dan/10god','0.3 - 0.5 dan/10god','0.5 - 0.7 dan/10god','0.7 - 0.9 dan/10god','0.9 - 1.1 dan/10god','> 1.1 dan/10god']
    
                    m=mmax
                    for k in np.arange(0,7):
                        ax.plot([xx], [yy-k*korak],'o', color='orange', markersize=m)
                        m=m-4

                    m=mmin
                    for k in np.arange(7,14):
                        ax.plot([xx], [yy-k*korak],'o', color='cyan', markersize=m)
                        m=m+4

                    for k in np.arange(0,14):
                        ax.annotate(lab[k], xy=(xx,yy-k*korak), xytext=(xx+korak,yy-k*korak))        
                                
                elif i==4:
                    x0=13.5; y0=44.8; korak=21000; mmax=27; mmin=3
                    xx,yy=map_ax(x0,y0)
                    lab=['< -0.12 mm/10god','-0.1 - -0.12 mm/10god','-0.08 - -0.1 mm/10god','-0.06 - -0.08 mm/10god','-0.04 - -0.06 mm/10god','-0.02 - -0.04 mm/10god','0 - -0.02 mm/10god','0 - 0.02 mm/10god','0.02 - 0.04 mm/10god','0.04 - 0.06 mm/10god','0.06 - 0.08 mm/10god','0.08 - 0.1 mm/10god','0.1 - 0.12 mm/10god','> 0.12 mm/10god']
    
                    m=mmax
                    for k in np.arange(0,7):
                        ax.plot([xx], [yy-k*korak],'o', color='orange', markersize=m)
                        m=m-4

                    m=mmin
                    for k in np.arange(7,14):
                        ax.plot([xx], [yy-k*korak],'o', color='cyan', markersize=m)
                        m=m+4

                    for k in np.arange(0,14):
                        ax.annotate(lab[k], xy=(xx,yy-k*korak), xytext=(xx+korak,yy-k*korak)) 
        
    
        #---Spremanje slika
        fig.savefig('{}_{}.png'.format(IND[i],SCEN[s]))           
        plt.show()
